# %%
import pandas as pd
import matplotlib.pyplot as plt
d = {'x' : [1., 2., 3., 4.], 'y1' : [8., 6., 4., 2.], 'y2' : [-4., 13., 2.2, -1.1]}
df = pd.DataFrame(d)
ax = df.plot(x='x', y=['y1'], linestyle='-', color='b')
df.plot(x='x', y=['y2'], linestyle='--', color='y', ax=ax)
l1 = plt.axvline(x=1.5, color='r', linestyle='--', label='vline1.5custom')
l2 = plt.axvline(x=3.5, color='k', linestyle='--', label='vline3.5custom')
#move ax.legend after axvlines and get_label
ax.legend(labels=['y1custom', 'y2custom',l1.get_label(),l2.get_label()])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
Methods = ['Bicubic','A+','RFL',   'SelfExSR','SCN', 'ESPCN', 'SRCNN', 'FSRCNN', 'VDSR', 'DRCN','LapSRN','DRRN', 'MemNet', 'MCISIR(Ours)']
Set5_x8_PSNR = [24.40, 25.53, 25.38, 25.49, 25.59, 25.75, 25.33, 25.60, 25.93, 25.93, 26.14, 26.18, 26.16, 26.28]
plt.plot(Methods,Set5_x8_PSNR, marker='o', markerfacecolor='blue', markersize=8, color='blue', linewidth=1,label="Set5_x8")
Set14_x8_PSNR = [ 23.10, 23.89, 23.79, 23.92, 24.02, 24.21, 23.76, 24.00, 24.26, 24.25, 24.35, 24.42, 24.38, 24.39]
plt.plot(Methods, Set14_x8_PSNR, marker='o', markerfacecolor='green', markersize=8, color='green', linewidth=1,label="Set14_x8")
BSDS100_x8_PSNR = [ 23.67, 24.21, 24.13, 24.19, 24.30, 24.37, 24.13, 24.31, 24.49, 24.49, 24.54, 24.59, 24.58, 24.61]
plt.plot(Methods, BSDS100_x8_PSNR, marker='o', markerfacecolor='red', markersize=8, color='red', linewidth=1,label="BSDS100_x8")
Urban100_x8_PSNR = [ 20.74, 21.37, 21.27, 21.81, 21.52, 21.59, 21.29, 21.45, 21.70, 21.71, 21.81, 21.88, 21.89,21.90]
plt.plot(Methods, Urban100_x8_PSNR, marker='o', markerfacecolor='cyan', markersize=8, color='cyan', linewidth=1,label="Urban100_x8")
Manga109_x8_PSNR = [ 21.47, 22.39,22.28, 22.99, 22.68,22.83,22.46,22.72,23.16,23.20,23.39,23.60,23.56,23.62]
plt.plot(Methods, Manga109_x8_PSNR, marker='o', markerfacecolor='orange', markersize=8, color='orange', linewidth=1,label="Manga109_x8")

plt.grid(True, which="both")
plt.ylabel('PSNR (dB)')
l1 = plt.axvline(x=2.5, color='k', linestyle='--')
l2 = plt.axvline(x=6.5, color='k', linestyle='--')
ax.legend(labels=['y1custom', 'y2custom',l1.get_label(),l2.get_label()])
plt.title('Quantitative Comparisons on different Benchmark Datasets')
plt.xticks(rotation=90, size=12)
plt.yticks(rotation=90, size=12)
plt.legend()
plt.show()
# Out:
# C:\Users\user\anaconda3\envs\gputest1\lib\site-packages\ipykernel_launcher.py:19: UserWarning: The handle <matplotlib.lines.Line2D object at 0x000001E5FB8E5748> has a label of '_line5' which cannot be automatically added to the legend.
# C:\Users\user\anaconda3\envs\gputest1\lib\site-packages\ipykernel_launcher.py:19: UserWarning: The handle <matplotlib.lines.Line2D object at 0x000001E5FB8E5248> has a label of '_line6' which cannot be automatically added to the legend.
